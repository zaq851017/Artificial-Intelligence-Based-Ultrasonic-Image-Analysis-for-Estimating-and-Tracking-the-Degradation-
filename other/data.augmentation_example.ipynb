# %%
import sys
from PIL import Image
from torchvision import transforms as tfs

# %%
im = Image.open('./frame030.jpg')
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x352 at 0x7F7EB0D23B80>

# %%
v_flip = tfs.RandomVerticalFlip()(im)
v_flip
# Out:
# <PIL.Image.Image image mode=RGB size=416x352 at 0x7F7F5C08B790>

# %%
bright_im = tfs.ColorJitter(brightness=1.5)(im)
bright_im
# Out:
# <PIL.Image.Image image mode=RGB size=416x352 at 0x7F7EB063D4C0>
